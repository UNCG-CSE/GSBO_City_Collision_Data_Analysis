# %%
import pandas as pd
from matplotlib import pyplot as plt
import os

# %%
current_directory = "data/Excel_sheets"
files = os.listdir(current_directory)
data = pd.read_excel(current_directory + "/" +files[2])
files
# Out:
# ['All_Collisions.xlsx',
#  'CrosswalkLocations.xlsx',
#  'Fatalities.xlsx',
#  'PedestrianCollisions.xlsx',
#  'PedestrianSignals.xlsx',
#  'RegulatoryandWarningStreetSigns.xlsx',
#  'TrafficSignalLocations.xlsx']

# %%
countY = 0
countN = 0
for i in data["ALCOHOL"]:
    if i == "Y":
        countY += 1
    else:
        countN += 1
print(countY, countN)
# Out:
# 35 170

# %%
plt.bar([1,2],[countN,countY])
plt.xticks([1,2],["No","Yes"])
plt.ylabel("Occurances of alcohol")
plt.xlabel("Is there alcohol?")

# %%
data
# Out:
#      OBJECTID  Shape     CASE_NUM BIPED                      Address  \
# 0           1    NaN  20120424146   NaN    MUIRS CHAPEL RD/ MEADE DR
# 1           2    NaN  20120425089     P            307 S EDWARDIA ST
# 2           3    NaN  20120430007   NaN  W FRIENDLY AVE/HILLCREST DR
# 3           4    NaN  20120510305   NaN          I 73 S. RAMP/I-40 E
# 4           5    NaN  20120524013   NaN         US 29S/ PHILLIPS AVE
# ..        ...    ...          ...   ...                          ...
# 200       201    NaN  20190714204     P                  E CONE BLVD
# 201       202    NaN  20190718080   NaN                 MCCONNELL RD
# 202       203    NaN  20190726143   NaN              DRAWBRIDGE PKWY
# 203       204    NaN  20190801270   NaN                        US 29
# 204       205    NaN  20190820122   NaN          GUILFORD COLLEGE RD
#
#     Accident_Date Crash_Day Crash_Month  Crash_Year  \
# 0      2012-04-24   TUESDAY       APRIL        2012
# 1      2012-04-26  THURSDAY       APRIL        2012
# 2      2012-04-30    MONDAY       APRIL        2012
# 3      2012-05-10  THURSDAY         MAY        2012
# 4      2012-05-24  THURSDAY         MAY        2012
# ..            ...       ...         ...         ...
# 200    2019-07-14    SUNDAY        JULY        2019
# 201    2019-07-18    SUNDAY        JULY        2019
# 202    2019-07-26    FRIDAY        JULY        2019
# 203    2019-08-01  THURSDAY      AUGUST        2019
# 204    2019-08-20   TUESDAY      AUGUST        2019
#
#                                         Accident_Cause  ... WORKZONE ALCOHOL  \
# 0    OPERATED VEHICLE IN AN ERRATIC, RECKLESS, CARE...  ...       NO       N
# 1                        INATTENTION/ IMPROPER BACKING  ...       NO       N
# 2          EXCEEDED AUTORIZED SPEED LIMIT/ALCOHOL USE/  ...       NO       Y
# 3    EXCEEDED SAFE SPEED FOR CONDITIONS/ PASSED ON ...  ...       NO       N
# 4    OPERATED VEHICLE IN AN ERRATIC, RECKLESS, CARE...  ...       NO       Y
# ..                                                 ...  ...      ...     ...
# 200                                            UNKNOWN  ...       NO       N
# 201           DISREGARDED TRAFFIC SIGNALS/ INATTENTION  ...       NO       N
# 202  EXCEEDED AUTHORIZED SPEED LIMIT/ CROSSED CENTE...  ...       NO       N
# 203  CROSSED CENTERLINE/GOING WRONG WAY/ OPERATED V...  ...       NO       N
# 204                 CROSSED CENTERLINE/GOING WRONG WAY  ...       NO       N
#
#     SEATBELTS ACCIDENT_TIME SEX_FAT1 RACE_FAT1  AGE_FAT1  \
# 0           Y         12:20        F         W      31.0
# 1         NaN         11:20        M         W      56.0
# 2           Y         00:28        M         W      40.0
# 3           Y         17:26        M         W      44.0
# 4           Y         00:23        M         H      21.0
# ..        ...           ...      ...       ...       ...
# 200       NaN   10:34:00 PM        M         W      60.0
# 201         Y    6:42:00 AM        M         W      43.0
# 202         N    2:22:00 PM        M         W      81.0
# 203         Y   10:18:00 PM        F         B      56.0
# 204         Y    9:59:00 AM        F         W      73.0
#
#                    COMMENTS          X          Y
# 0                       NaN -79.873083  36.083239
# 1                       NaN -79.885971  36.066957
# 2                       NaN -79.812691  36.074823
# 3                       NaN -79.916063  36.064793
# 4                       NaN -79.764735  36.100016
# ..                      ...        ...        ...
# 200                     NaN -79.753520  36.112765
# 201                     NaN -79.757390  36.063220
# 202                     NaN -79.874968  36.132137
# 203  FAT_1 DIED ON 8/5/2019 -79.748803  36.124220
# 204                     NaN -79.913522  36.055535
#
# [205 rows x 29 columns]

# %%
def extractDate(data):
    dates = []
    datetimes = data.Accident_Date.unique()
    for date in datetimes:
        year = str(date)[0:4]
        month = str(date)[5:7]
        day = str(date)[8:10]
        dates.append({"month":month, "day": day, "year":year})
    return dates

# %%
crash_counts_by_year = (data.groupby("Crash_Year").count())["OBJECTID"]
crash_counts_by_year
# Out:
# Crash_Year
# 2012    22
# 2013    24
# 2014    22
# 2015    21
# 2016    25
# 2017    35
# 2018    30
# 2019    26
# Name: OBJECTID, dtype: int64

# %%
dates = extractDate(data)
dates = pd.DataFrame(dates)

def getCountsByMonth(dates):
    dictionary = {}
    years = dates.year.unique()
    for year in years:
        year_table = dates[dates["year"] == year]
        monthcounts = pd.DataFrame(year_table.groupby("month").count()["day"])
        monthcounts = monthcounts.rename(columns = {"day":"frequency"})
        dictionary[year] = monthcounts
    return dictionary

dictionary = getCountsByMonth(dates)
total_counts = dictionary["2012"]
years = list(dictionary.keys())[1:]
for year in years:
    total_counts = total_counts.add(dictionary[year], fill_value = 0)

    
for i in range(len(total_counts)):
    total_counts["frequency"][i] = total_counts["frequency"][i]/len(total_counts)
years
# Out:
# ['2013', '2014', '2015', '2016', '2017', '2018', '2019']

# %%
import requests
import json
path = "data/weather_data"
files = os.listdir(path)
file = open(path + "/" + files[1], "r")
data = json.load(file)
file.close()
data = pd.DataFrame(data)
data
# Out:
#         city_id                                               main  \
# 0       4169510  {'temp': 300.07, 'temp_min': 299.82, 'temp_max...
# 1       4169510  {'temp': 300.85, 'temp_min': 299.82, 'temp_max...
# 2       4169510  {'temp': 300.92159375, 'temp_min': 300.9215937...
# 3       4169510  {'temp': 300.9931875, 'temp_min': 300.9931875,...
# 4       4169510  {'temp': 301.06478125, 'temp_min': 301.0647812...
# ...         ...                                                ...
# 309701  4815207  {'temp': 290.15, 'temp_min': 287.15, 'temp_max...
# 309702  4815207  {'temp': 290.31, 'temp_min': 288.15, 'temp_max...
# 309703  4815207  {'temp': 288.85, 'temp_min': 286.15, 'temp_max...
# 309704  4815207  {'temp': 286.4, 'temp_min': 283.71, 'temp_max'...
# 309705  4815207  {'temp': 285.45, 'temp_min': 282.04, 'temp_max...
#
#                             wind       clouds  \
# 0       {'speed': 3, 'deg': 150}  {'all': 20}
# 1       {'speed': 5, 'deg': 170}  {'all': 20}
# 2       {'speed': 5, 'deg': 169}  {'all': 22}
# 3       {'speed': 5, 'deg': 169}  {'all': 24}
# 4       {'speed': 5, 'deg': 168}  {'all': 26}
# ...                          ...          ...
# 309701  {'speed': 4, 'deg': 250}  {'all': 20}
# 309702  {'speed': 3, 'deg': 260}  {'all': 40}
# 309703  {'speed': 4, 'deg': 280}   {'all': 1}
# 309704  {'speed': 1, 'deg': 290}   {'all': 1}
# 309705  {'speed': 2, 'deg': 269}   {'all': 1}
#
#                                                   weather          dt  \
# 0       [{'id': 801, 'main': 'Clouds', 'description': ...  1349096400
# 1       [{'id': 801, 'main': 'Clouds', 'description': ...  1349100000
# 2       [{'id': 801, 'main': 'Clouds', 'description': ...  1349103600
# 3       [{'id': 801, 'main': 'Clouds', 'description': ...  1349107200
# 4       [{'id': 802, 'main': 'Clouds', 'description': ...  1349110800
# ...                                                   ...         ...
# 309701  [{'id': 801, 'main': 'Clouds', 'description': ...  1572206400
# 309702  [{'id': 802, 'main': 'Clouds', 'description': ...  1572210000
# 309703  [{'id': 800, 'main': 'Clear', 'description': '...  1572213600
# 309704  [{'id': 800, 'main': 'Clear', 'description': '...  1572217200
# 309705  [{'id': 800, 'main': 'Clear', 'description': '...  1572220800
#
#                                dt_iso rain snow
# 0       2012-10-01 13:00:00 +0000 UTC  NaN  NaN
# 1       2012-10-01 14:00:00 +0000 UTC  NaN  NaN
# 2       2012-10-01 15:00:00 +0000 UTC  NaN  NaN
# 3       2012-10-01 16:00:00 +0000 UTC  NaN  NaN
# 4       2012-10-01 17:00:00 +0000 UTC  NaN  NaN
# ...                               ...  ...  ...
# 309701  2019-10-27 20:00:00 +0000 UTC  NaN  NaN
# 309702  2019-10-27 21:00:00 +0000 UTC  NaN  NaN
# 309703  2019-10-27 22:00:00 +0000 UTC  NaN  NaN
# 309704  2019-10-27 23:00:00 +0000 UTC  NaN  NaN
# 309705  2019-10-28 00:00:00 +0000 UTC  NaN  NaN
#
# [309706 rows x 9 columns]
